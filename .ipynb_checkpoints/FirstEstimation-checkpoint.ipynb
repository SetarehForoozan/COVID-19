# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# %%
def pandemic(k,t):
    
    S_H = k[0]
    S_M = k[1]
    S_L = k[2]
    I_H = k[3]
    I_M = k[4]
    I_L = k[5]  
    
    dS_Hdt = -ps['beta_H'] * (ps['alpha'] * I_H +         I_M +         I_L) * S_H +  ps['eta_MH'] * S_M
    dS_Mdt = -ps['beta_M'] * (        I_H + ps['alpha'] * I_M +         I_L) * S_M - (ps['eta_MH'] + ps['eta_ML']) * S_M
    dS_Ldt = -ps['beta_L'] * (        I_H +         I_M + ps['alpha'] * I_L) * S_L +  ps['eta_ML'] * S_M
    
    dI_Hdt =  ps['beta_H'] * (ps['alpha'] * I_H +         I_M +         I_L) * S_H - ps['gamma_H'] * I_H 
    dI_Mdt =  ps['beta_M'] * (        I_H + ps['alpha'] * I_M +         I_L) * S_M - ps['gamma_M'] * I_M 
    dI_Ldt =  ps['beta_L'] * (        I_H +         I_M + ps['alpha'] * I_L) * S_L - ps['gamma_L'] * I_L 
    
    return [dS_Hdt, dS_Mdt, dS_Ldt, dI_Hdt, dI_Mdt, dI_Ldt]

# %%
#Initial conditions and t range
stp = 0.1
t = np.arange(0,15, stp)

# %%
colors = ['r-','y-','g-','r--','y--','g--']

# %%
fig = plt.figure(figsize=(18,6))
#initial conditions 0
k0 = [0.6, 0.3, 0.1, 0, 0, 0.1]              
ps = {'gamma_H' : 1, 'gamma_M' : 1 ,'gamma_L' : 1,
            'beta_H'  : 1,  'beta_M' : 1 ,'beta_L' : 1,
            'alpha'   : 10,
            'eta_MH'  : 0.1, 'eta_ML' : 0.1}        #parameter space
ax = fig.add_subplot(1,2,1, xlabel = 'time', ylabel='S/I', title='', facecolor = 'lightgrey')
k = odeint(pandemic,k0,t)
for i in range(6):
        ax.plot(t,k[:,i], colors[i], linewidth=2.0, alpha = 1)

# %%
fig = plt.figure(figsize=(18,6))
#initial conditions 0
k0 = [0.6, 0.3, 0.1, 0, 0, 0.1]              
ps = {'gamma_H' : 1, 'gamma_M' : 1 ,'gamma_L' : 1,
            'beta_H'  : 1,  'beta_M' : 1 ,'beta_L' : 1,
            'alpha'   : 0.1,
            'eta_MH'  : 0, 'eta_ML' : 0}        #parameter space
ax = fig.add_subplot(1,2,1, xlabel = 'time', ylabel='S/I', title='', facecolor = 'lightgrey')
k = odeint(pandemic,k0,t)
for i in range(6):
        ax.plot(t,k[:,i], colors[i], linewidth=2.0, alpha = 1)
